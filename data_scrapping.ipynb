# %% [markdown]
# <a href="https://colab.research.google.com/github/mamurov0104-prog/computer-vision/blob/main/data_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader
downloader.download(
    "uzbek pilaf plov food",
    limit=100,
    output_dir='/content/pilaf_images',
    adult_filter_off=True,
    force_replace=False,
    timeout=60
)
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 60 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/fe/26/e5/fe26e5a1ee21d43328791fb76ebb57de.png
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://media.licdn.com/dms/image/v2/C4D22AQEYb103j8xa2A/feedshare-shrink_2048_1536/feedshare-shrink_2048_1536/0/1578076586356?e=2147483647&v=beta&t=e8x1w-w1ETLskpWh9VGBZqFg0kpnN36ugFbKUbKyHsM
# [!] Issue getting: https://media.licdn.com/dms/image/v2/C4D22AQEYb103j8xa2A/feedshare-shrink_2048_1536/feedshare-shrink_2048_1536/0/1578076586356?e=2147483647&v=beta&t=e8x1w-w1ETLskpWh9VGBZqFg0kpnN36ugFbKUbKyHsM
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #2 from https://img.travelnaut.com/web/db/photos/attraction/eu/ad/all_of_andorra/ma/madriu-perafita-clarorvalley-photo.jpg?format=webp&width=2048&quality=75
# [%] File Downloaded!
#
# ...

# %%
# !rm -rf "/content/drive"
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os, shutil

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

# %%
from bing_image_downloader import downloader
downloader.download(
    "uzbek shashlik kebab food",
    limit=100,
    output_dir='/content/kebab_images',
    adult_filter_off=True,
    force_replace=False,
    timeout=60
)
# Out:
# [%] Downloading Images to /content/kebab_images/uzbek shashlik kebab food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/736x/33/58/ce/3358cec50f5bcc46edc6435681d5dca6.jpg
# [%] File Downloaded!
#
#
#
# [!!] Indexing page: 2
#
# [%] Indexed 1 Images on Page 2.
#
# ...
#
# [%] Downloading Image #2 from https://2.bp.blogspot.com/-PSV3qOvAfjM/Ujrsb-vkPVI/AAAAAAAACvI/33OaqWv2rKk/s1600/Ada+apa+denganmu.PNG
# [%] File Downloaded!
#
#
#
# [!!] Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ...
#
# [%] Downloading Image #3 from https://www.homosensual.com/wp-content/uploads/2022/06/bandera-gay.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://img.freepik.com/fotos-premium/retrato-pareja-masculina-gay-multietnica-sosteniendo-bandera-simbolo-lgbt-arco-iris-al-atardecer_242111-27546.jpg?w=2000
# [%] File Downloaded!
#
# ...

# %%
import os, shutil

source_dir = '/content/kebab_images/uzbek shashlik kebab food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)
